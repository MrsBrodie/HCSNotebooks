# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Test yourself : Modular Design Tasks</h1><hr>
#
# </div>
#
# ## Task 4 Month Converter

# %% [markdown]
# You are to write a program that will allow the user to enter the number of the month and display which a message
# stating whether it has 28(or 29), 30 or 31 days. Input should be validated so that only input between 1 and 12 (inclusive)
# is accepted. The top level design below should be refined as appropriate.

# %% [markdown]
# ![TYtask4data.PNG](attachment:TYtask4data.PNG)

# %%
# Task 4 Month Converter
#Write your code here

# %% [markdown]
# ## Extension
# The user has now requested a modification to the program. They want the program to display the actual month as
# well.
# For example:
# ![ext1.PNG](attachment:ext1.PNG)

# %%
#Task 4 Extension
# Write your code here
