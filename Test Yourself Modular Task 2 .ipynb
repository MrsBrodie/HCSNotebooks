# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Test yourself : Modular Design Tasks</h1><hr>
#
# </div>
#
# ## Task 2 Fahrenheit Converter

# %% [markdown]
# You are going to create a program that uses a function to take in the value in Celsius and convert it into Fahrenheit.
# The output will be formatted to two decimal places. The formula is: (celsius * 1.8) + 32. The top level design below
# should be refined as appropriate.
# ![tytask2.PNG](attachment:tytask2.PNG)

# %%
#Fahrenheit Converter
#Write your code here
