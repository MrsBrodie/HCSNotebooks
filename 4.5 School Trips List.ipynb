# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 4.5: School Trips List</h1>
#
# </div>
# <hr>
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	To read from a file and implement a counting occurrences algorithm
#
# </div>
#
# ---

# %% [markdown]
# A school is organising a projects week and a list has been collated of the <b>100</b> names, genders of the pupils and the trip they have chosen. <br>
# You have to write a program to read in the contents of the file  and count the amount on each trip. The school trips on offer are: <b>London,Paris,BMX,Mountain Biking and Gorge Walking.  </b><br>
# A sample of the file (<b>schooltrips.csv</b>) is shown below:
#
# ![note1.PNG](attachment:note1.PNG)
# The output from your program should be the total amount of pupils on each trip should be displayed. <br> A file should
# then be created for <b>each</b> trip leader containing the <b>number</b> of pupils on that respective trip.

# %% [markdown]
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# ![note1.PNG](attachment:note1.PNG)

# %%
# 4.5. Schools Trip List
# Make sure that the file schooltrips.csv is in the same folder.
# Write your code here.
