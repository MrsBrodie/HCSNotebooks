# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Test yourself : Modular Design Tasks</h1><hr>
#
# </div>
#
# ## Task 3 Gas Bill Converter

# %% [markdown]
# When you submit a gas meter reading it converts the units used to kilowatt hours (kWh).  When receiving a bill your
# previous and current reading is used to calculate the number of imperial units and then this number is converted to
# kilowatt hours. Each kilowatt hour costs  3.74p. VAT is also charged on the total due at 5%.
# Create a function that will allow you to pass in the previous reading, current reading , calculate the number of
# kilowatt hours used (see formula below) and return the amount due (rounded to two decimal places).

# %% [markdown]
# ![outputgas.PNG](attachment:outputgas.PNG)

# %% [markdown]
# ![ty3dataflkow.PNG](attachment:ty3dataflkow.PNG)

# %%
# Gas bill converter 
# Write your code here
