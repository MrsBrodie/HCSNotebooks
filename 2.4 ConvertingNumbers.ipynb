# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 2.4 : Converting Numbers</h1><hr>
#
# </div>
#
# ---
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	 To use the <b>int</b> function to validate if a number is an integer or real number.<br>
# </div>
#
# ---

# %% [markdown]
# We have used this before but the <b>int()</b> function will convert a value into an integer variable. There is no rounding
# performed the decimal portion of any real number is simply truncated.
# See the example below:![2.4output.PNG](attachment:2.4output.PNG)

# %% [markdown]
# ![2.4Extension.PNG](attachment:2.4Extension.PNG)

# %%
# 2.4 Converting Numbers
# Write your code here
