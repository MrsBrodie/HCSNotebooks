# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 5.3: Baking Competition</h1><hr>
#
# </div>

# %% [markdown]
# A group of local schools took part in a competition to find the best amateur baker. <br>
# There are 20 contestants each from 5 different Schools <br><br>
# ❏	AiryBrae<br>
# ❏	Inverlamond Academy<br>
# ❏	Linlathen<br>
# ❏	St Saviours<br>
# ❏	Aberdeen Academy.  <br><br>
# AiryBrae and Linlathen are Primary Schools and the rest are Secondary schools. Each contestant will have a maximum score of 30). They were recorded as below
# A sample of the file is shown below:

# %% [markdown]
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# Your task is to open and read the file called Baking.csv. The data must be stored in an appropriate data structure. <br>
# The program must: <br>
# ❏ Display the details of the best primary and secondary pupil. <br>
# ❏ Display the School with the Highest Average Score <br>
# ❏ Write the pupil name and school name of the best primary and best secondary pupil to a new text file <br><br>
# Your output should be similar to below:
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# 1. When reading the file it would be useful if you could read them into an array that held either primary or
# secondary pupils  at the beginning of the process.
# Declare the following record structures to use when reading the file.
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# 2.	Use the following code for your ReadFile function:
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# 3.	Now <b>alter the above code </b>to deal with Secondary Pupils - storing them in an array called <b>secondarypupils:</b>
# 4.	You can now attempt the rest of the program.

# %%
# 5.3 Baking Competition
# Make sure the file baking.csv is in the same folder
# Write your cvode here
