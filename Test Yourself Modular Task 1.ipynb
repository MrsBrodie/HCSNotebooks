# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Test yourself : Modular Design Tasks</h1><hr>
#
# </div>
#
# ## Task 1 VAT Calculator

# %% [markdown]
# Create a program that will allow a user to enter a price (exc VAT) and then display the price inclusive of VAT (rounded
# to two decimal places). At present VAT is 20% This should be written in a modular manner and data flow identified.
# The top level design below should be refined as appropriate.

# %% [markdown]
# ![TYtask1.PNG](attachment:TYtask1.PNG)

# %%
# Write your code here
