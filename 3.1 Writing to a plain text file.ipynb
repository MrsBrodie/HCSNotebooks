# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 3.1 : Writing to a plain text file</h1><hr>
#
# </div>
#
# ---
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	 To write text to a plain text file <br>
# </div>
#
# ---

# %% [markdown]
# ## Required Reading: 4 File Handling and Structures Presentation

# %% [markdown]
# ![3.1dataflow.PNG](attachment:3.1dataflow.PNG)

# %% [markdown]
# 1. Create a function called WriteFile that will have one parameter called filecontents. This is the text that will be
# written to the file ![3.1code1.png](attachment:3.1code1.png)

# %% [markdown]
# 2.	We will now ask the user to enter their message and pass it to the WriteFile function.![3.1code2.png](attachment:3.1code2.png)

# %% [markdown]
# 3.	Run the program to test.

# %%
# Write your code here

# %% [markdown]
# You will see that you get an error message.!![3.4error%20code-2.PNG](attachment:3.4error%20code-2.PNG)
# <br> This is because the file does not exist and we haven't given Python the instructions to make it.

# %% [markdown]
# 4.	So we will alter the mode of the file to w - modify your writefile subroutine as shown below and retest the program.
# ![3.4code2.png](attachment:3.4code2.png)

# %%
# Write your code here

# %% [markdown]
# 5.	You will notice that the file is now created in the same folder where you Python program was saved.
# 6.	If you run the program twice you will notice that the contents of the file are being overwritten.
# 7.	We will modify the program so that the contents of the file will be appended (written onto the end of the file) and each message will be on a new line.
# 8.	Save a new version of your file as (WriteFile2)
# 9.	Modify your subroutine to the following:
# ![3.4code3.png](attachment:3.4code3.png)
# 10.	Now run and test your program.
