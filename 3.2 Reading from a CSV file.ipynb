# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 3.2 : Reading from a CSV file</h1><hr>
#
# </div>
#
#
# ---
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	To read a CSV file and store it within two parallel arrays<br>
# </div>
#
# ---

# %% [markdown]
# Your task is to read the contents of a file which contains details of 20 pupil names and their guidance house.
# The structure of the file is as follows:
# ![3.2text.PNG](attachment:3.2text.PNG)

# %% [markdown]
# ![3.2text2.PNG](attachment:3.2text2.PNG)

# %% [markdown]
# ![3.2refine.PNG](attachment:3.2refine.PNG)

# %% [markdown]
# 1. Create the subroutine definitions from the data flow given above.
# 2. Implement the following  function which will read the file and split it into an array by using the comma as a
# separator. As it will be used many different times it is heavily commented to explain the function of each line.

# %% [markdown]
# ![reading3.2.PNG](attachment:reading3.2.PNG)

# %% [markdown]
# Now we will have to iterate through these arrays to display the content.
# 3. The DisplayContents function is shown below:
# ![3.2display.png](attachment:3.2display.png)
# 4.	When you run this program you will notice that the output isn’t formatted correctly. One way to do this is to format the string to be a fixed length (add some padding to the right hand side. Alter your display subroutine to the following:

# %% [markdown]
# ![display3.png](attachment:display3.png)
# 	Now run and retest your program.

# %%
# 3.2 Reading from a CSV file 
# Write your code here
