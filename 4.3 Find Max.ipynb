# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 4.3: Find Max</h1>
#
# </div>
# <hr>
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔ To implement a find maximum algorithm
# </div>
#
# ---

# %% [markdown]
# ## Required Reading: 5 Standard Algorithms Presentation
#
# Write a program which displays an existing list of scores in the file called <b>scores.csv</b> which are read from a file The program should then display a message showing the highest score in the list.
# The scores are  integers between 0 and 9999.
#
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# ![note1.PNG](attachment:note1.PNG)

# %% [markdown]
# What to do now
# 1. Create a subroutine to read the file <b>Scores.csv</b> and store in two parallel arrays called <b>names</b> and <b>scores</b>. The
# arrays should be initialised to <b>50</b> elements.
# 2. When reading from the file ensure that you cast the score to an integer value so that when using it later in the
# program it is not treated as a string:

# %% [markdown]
# ![note1.PNG](attachment:note1.PNG)
# 3.	In your FindMax subroutine add the following code to search through an array and display the maximum score found:

# %% [markdown]
# ![Picture5.png](attachment:Picture5.png)
# 4.	Now call the MaxScore function and then run and test your program.

# %% [markdown]
# <b>What to do now</b>
#
# Use this function as a basis to find the <b>minimum</b> score.

# %%
# Find Max
# Make sure that the file Scores.csv is in the same folder
# Write your code here.
