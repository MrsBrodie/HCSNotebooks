# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>Exercise 5.4: Skiing Competition</h1><hr>
#
# </div>

# %% [markdown]
# In a local downhill skiing competition the competitors have to pass through a maximum of 9 gates. There are 4 teams  <br>
# ❏ Aberdeen Juniors, Slalom Fun, Dundee Dry and Glasgow Juniors <br><br>
# There are 5 competitors from each team <br>
# For every gate missed or hit there is a 0.5 second penalty. The last piece of information in the file e.g. 1269 is a list of
# the gate numbers they faulted at. So for example 1269  would mean that there were 4 gates missed or hit so there is a
# 2.0 second penalty to be added. <br><br>
# The competitors name, race number, team, race time along with the penalties are stored in the file <b>skiing.csv </b>
# A sample of data is shown below:![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# Create a program that will <br>
# ❏ Read and process the file to calculate the total time for each competitor ( incorporating any penalties) <br>
# ❏ Store the data in an appropriate record structure <br>
# ❏ List the final times per team <br>
# ❏ Display the individual winner (individual best time inclusive of penalties) <br>
# Your output should be similar to below: ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# <b>Extension</b> <br>
# ❏ Display the winning team ( best total time) and  in the event of a tie the team with the lowest amount of
# penalties will win. <br>
# For example: ![Capture.PNG](attachment:Capture.PNG)

# %%
# 5.4 Skiing COmpetition
# Make sure that the file skiing.csv is in the same folder
# Write your code here
